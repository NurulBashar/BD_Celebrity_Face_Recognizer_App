# %%
print("hello")
# Out:
# hello

# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.8 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/project/Data
# Out:
# /content/drive/MyDrive/project/Data

# %%
version = 4
img_path = '/content/drive/MyDrive/project/test_image'
model_path = f'models/celebrity_model-v4{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1

# %%
img = Image.open(f'{img_path}/nis.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x88>

# %%
model.predict(f'{img_path}/nis.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Tahsan Khan',
#  tensor(17),
#  tensor([1.7531e-01, 2.1160e-05, 1.5668e-02, 2.5568e-05, 8.0964e-05, 1.6358e-05,
#          3.4904e-05, 4.0652e-03, 5.4197e-03, 2.4775e-06, 3.7242e-03, 1.8728e-06,
#          4.5331e-03, 8.0091e-05, 1.9936e-06, 1.2372e-06, 8.7993e-06, 7.9100e-01,
#          2.6624e-06]))

# %% [markdown]
# #Inference 2

# %%
img = Image.open(f'{img_path}/dr.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x73>

# %%
model.predict(f'{img_path}/dr.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Dr. Muhammad Yunus',
#  tensor(5),
#  tensor([7.5474e-07, 2.1330e-07, 2.4758e-07, 4.0389e-07, 6.0659e-05, 9.9935e-01,
#          2.3437e-07, 5.0319e-04, 8.0644e-08, 5.7592e-08, 1.9066e-07, 1.0057e-08,
#          9.8636e-08, 1.0988e-06, 1.8904e-08, 7.0821e-07, 4.4619e-06, 7.4084e-05,
#          4.2382e-07]))

# %% [markdown]
# #Inference 3

# %%
img=Image.open(f"{img_path}/tamim.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x72>

# %%
model.predict(f"{img_path}/tamim.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Tamim Iqbal',
#  tensor(18),
#  tensor([5.7013e-08, 6.5159e-05, 1.2611e-06, 1.2084e-04, 2.1004e-08, 3.3226e-06,
#          4.2979e-07, 2.2530e-08, 1.6506e-07, 1.5970e-06, 4.1513e-06, 1.5687e-05,
#          3.5067e-06, 1.9994e-07, 1.6760e-07, 3.5999e-05, 3.4188e-06, 1.0358e-07,
#          9.9974e-01]))

# %% [markdown]
# #Inference 4

# %%
img=Image.open(f"{img_path}/sakib f.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=109x128>

# %%
model.predict(f"{img_path}/sakib f.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Shakib Khan',
#  tensor(16),
#  tensor([4.3271e-08, 1.4685e-07, 5.5152e-06, 7.7103e-09, 7.5516e-08, 1.6720e-10,
#          1.4224e-06, 2.6008e-07, 3.5810e-09, 2.9741e-07, 2.7409e-04, 3.2313e-06,
#          3.4837e-07, 8.4152e-07, 9.7008e-07, 2.3421e-07, 9.9966e-01, 4.1357e-06,
#          5.0701e-05]))

# %%
jara.jpg

# %%
img=Image.open(f"{img_path}/jara.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=102x128>

# %%
model.predict(f"{img_path}/jara.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Joya Ahsan only Face',
#  tensor(9),
#  tensor([2.8426e-08, 3.6240e-05, 3.4643e-07, 1.8131e-07, 7.8670e-07, 1.0253e-07,
#          9.0282e-09, 3.2079e-08, 1.7568e-08, 9.9994e-01, 8.4286e-09, 2.1548e-08,
#          1.0055e-08, 2.2775e-07, 2.0433e-05, 1.3807e-08, 4.2931e-06, 3.5142e-09,
#          1.7612e-07]))

# %%
img=Image.open(f"{img_path}/OIP.jpeg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x93>

# %%
model.predict(f"{img_path}/OIP.jpeg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Joya Ahsan only Face',
#  tensor(9),
#  tensor([3.5476e-07, 7.6919e-06, 8.4877e-08, 1.6513e-10, 8.6513e-06, 2.7974e-09,
#          4.1655e-09, 7.5868e-09, 5.6760e-08, 9.9998e-01, 4.3510e-09, 2.3977e-09,
#          6.0194e-08, 1.2914e-07, 5.5096e-06, 2.9041e-08, 1.1828e-07, 2.1520e-08,
#          1.7541e-09]))

# %%
img=Image.open(f"{img_path}/nisah.jpg")
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x108>

# %%
model.predict(f"{img_path}/nisah.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Afran Nisho only Face',
#  tensor(0),
#  tensor([9.9977e-01, 7.6805e-08, 1.2487e-07, 5.6121e-08, 7.9074e-07, 2.3070e-08,
#          2.8903e-08, 2.7883e-08, 3.1370e-08, 7.8958e-09, 2.5532e-07, 7.6089e-08,
#          1.1443e-05, 3.3635e-08, 1.1691e-07, 3.7458e-07, 2.2029e-04, 1.5501e-07,
#          8.6520e-07]))
